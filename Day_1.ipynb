# %% [markdown]
# <a href="https://colab.research.google.com/github/bibhav1108/Build-with-AI/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('tttttttttttt')
# Out:
# tttttttttttt

# %%
name ="Bibhav\n"
age =21
college ="\nsrmcem"
print(name,age,college)
# Out:
# Bibhav
#  21
# srmcem

# %%
a,b = 12,21
a,b = b,a
print(a,b)
# Out:
# 21 12

# %%
a = 1.234
print(int(a))
# Out:
# 1

# %%
name =input ("Enter your name :")
age = int(input("Enter your age:"))
college = input ("Enter college name:")
# Out:
# Enter your name :Bibhav
# Enter your age:21
# Enter college name:Srmcem

# %%
a=10
b=20
print(a+b)
print(a-b)
print(a*b)
print(b/2)
print(b//2)
# Out:
# 30
# -10
# 200
# 10.0
# 10

# %%
age = int(input("Enter age :"))
if age>=18 :
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Enter age :17
# Not Eligible

# %%
marks= int(input("Enter marks :"))
if marks>=90:
  print("Grade A")
elif marks>=80:
  print("Grade B")
elif marks>=70:
  print("Grade C")
elif marks>=60:
  print("Grade D")
# Out:
# Enter marks :80
# Grade B

# %%
num = int(input("Enter number: "))

if num % 3 == 0 and num % 5 == 0:
    print("Divisible by 3 and 5")
elif num % 3 == 0:
    print("Divisible by 3")
elif num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 3 or 5")
# Out:
# Enter number: 15
# Divisible by 3 and 5

# %%
name = input("Enter name:")
age = int(input("Enter age:"))
pqercentage = int(input("Enter marks:"))
phone = int(input("Enter your mobile number:"))
if age<=20 and percentage>=60:
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Enter name:Bibhav
# Enter age:21
# Enter marks:61
# Enter your mobile number:8787878787
# Not Eligible

# %%
purchase=int(input("enter your total purchase"))
if purchase>40000:
  print("You are an icon")
elif purchase>32000 and purchase<=40000:
  print("You are an elite")
elif purchase>25000 and purchase<=32000:
  print("You are a select")
else :
  print("you are not an insider")
# Out:
# enter your total purchase80000
# You are an icon

# %%
a= int(input("Enter a:"))
b= int(input("Enter b:"))
operator=input("Enter operator:")
if operator=="+":
  print(a+b)
elif operator=="-":
  print(a-b)
elif operator=="*":
  print(a*b)
elif operator=="/":
  print(a/b)
# Out:
# Enter a:20
# Enter b:10
# Enter operator:+
# 30

# %%
balance = 5000

print("===== Welcome to ATM bitch =====")
print("1. Check Balance")
print("2. Deposit")
print("3. Withdraw")
print("4. Exit")

choice = int(input("Enter your choice: "))

if choice == 1:
    print("Your Balance is:", balance)

elif choice == 2:
    amount = int(input("Enter amount to deposit: "))
    balance = balance + amount
    print("Deposit Successful")
    print("Updated Balance:", balance)

elif choice == 3:
    amount = int(input("Enter amount to withdraw: "))

    if amount <= balance:
        balance = balance - amount
        print("Please collect your cash.")
        print("Remaining Balance:", balance)
    else:
        print("Insufficient Balance")

elif choice == 4:
    print("Thank you for using the ATM.")

else:
    print("Invalid Choice")
# Out:
# ===== Welcome to ATM bitch =====
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 2
# Enter amount to deposit: 1000
# Deposit Successful
# Updated Balance: 6000

# %% [markdown]
# >
